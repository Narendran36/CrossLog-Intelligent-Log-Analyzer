# %%
from google.colab import drive 
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_csv("drive/MyDrive/final_PT.csv")
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = df.dropna()

# %%
del df['Unnamed: 0']

# %%
df
# Out:
#          type                                                url  ...  access   ,,
# 0       Valid  /l_t@/_feu1wvhtpass2/1nieqnnrvnzktuasain/tg1ar...  ...     0.0  0.0
# 1       Valid  /inssgtz7ieltdsstbw7e/neqhmsdwu7imdb0etet/et/h...  ...     0.0  0.0
# 2       Valid                  /fonrnt/7n.d-4brssxb@tu/qghew.cfm  ...     0.0  0.0
# 3       Valid  /dyylkl.xd9cpu/4ot0ta/ts6xnrp1/hssh/a2cuerht/s...  ...     0.0  0.0
# 4       Valid  /2m6vlb1r37jspc/cwvv/mbar/oqrd0/msc/etceebwgi/...  ...     0.0  0.0
# ...       ...                                                ...  ...     ...  ...
# 126146  Valid  /tienda1/publico/registro.jsp?modo=registro&lo...  ...     0.0  0.0
# 126147  Valid  /tienda1/publico/registro.jsp?modo=registro&lo...  ...     0.0  0.0
# 126148  Valid  /tienda1/publico/registro.jsp?modo=registro&lo...  ...     0.0  0.0
# 126149  Valid  /tienda1/publico/registro.jsp?modo=registro&lo...  ...     0.0  0.0
# 126150  Valid  /tienda1/publico/registro.jsp?modo=registro&lo...  ...     0.0  0.0
#
# [125869 rows x 29 columns]

# %%
df.groupby('type').count()
# Out:
#              url  label      :   .bat  ...     ..   file  access     ,,
# type                                   ...
# CRLFi        229    229    229    229  ...    229    229     229    229
# LDAPi       2352   2352   2352   2352  ...   2352   2352    2352   2352
# OS          3420   3420   3420   3420  ...   3420   3420    3420   3420
# PT          3029   3029   3029   3029  ...   3029   3029    3029   3029
# SQLi       45573  45573  45573  45573  ...  45573  45573   45573  45573
# SSI         2349   2349   2349   2349  ...   2349   2349    2349   2349
# Valid      43368  43368  43368  43368  ...  43368  43368   43368  43368
# XPath       2454   2454   2454   2454  ...   2454   2454    2454   2454
# XSS         6636   6636   6636   6636  ...   6636   6636    6636   6636
# anomalous  16459  16459  16459  16459  ...  16459  16459   16459  16459
#
# [10 rows x 28 columns]

# %%
'''
i) Logistic Regression
ii) K-NN
iii) SVM
iv) SVM
v) Decsion Tree
vi) Random Forest
vii) Gradient Descent
'''

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn import metrics

X = list(df.columns[3:])
X_df = df[X]
Y_df = df['label']
X_train, X_test, Y_train, Y_test = train_test_split(X_df, Y_df, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

LR = LogisticRegression()
LR.fit(X_train,Y_train)

print('Accuracy of Logistic Regression classifier on training set: {:.2f}'
     .format(LR.score(X_train, Y_train)))
print('Accuracy of Logistic Regression classifier on test set: {:.2f}'
     .format(LR.score(X_test, Y_test)))

print()
Y_pred = LR.predict(X_test)
print(confusion_matrix(Y_test, Y_pred))
print()
metrics.accuracy_score(Y_test, Y_pred)
# Out:
# Accuracy of Logistic Regression classifier on training set: 0.98
# Accuracy of Logistic Regression classifier on test set: 0.98
#
# [[24456   104]
#  [  379   235]]
# 0.9808135377770716

# %%
 from sklearn import svm

 SVM = svm.LinearSVC()
 SVM.fit(X_train,Y_train)

 print('Accuracy of Linear SVM classifier on training set: {:.2f}'
     .format(SVM.score(X_train, Y_train)))
 print('Accuracy of Linear SVM classifier on test set: {:.2f}'
     .format(SVM.score(X_test, Y_test)))
 
print()
Y_pred = SVM.predict(X_test)
print(confusion_matrix(Y_test, Y_pred))
print()
metrics.accuracy_score(Y_test, Y_pred)
# Out:
# Accuracy of Linear SVM classifier on training set: 0.98
# Accuracy of Linear SVM classifier on test set: 0.98
#
# [[24490    70]
#  [  418   196]]
# 0.9806149201557162

# %%
from sklearn.ensemble import GradientBoostingClassifier

GB = GradientBoostingClassifier(random_state=0)
GB.fit(X_train, Y_train)

print('Accuracy of Gradient Boosting classifier on training set: {:.2f}'
     .format(GB.score(X_train, Y_train)))
print('Accuracy of Gradient Boosting classifier on test set: {:.2f}'
     .format(GB.score(X_test, Y_test)))

print()
Y_pred = GB.predict(X_test)
print(confusion_matrix(Y_test, Y_pred))
print()
metrics.accuracy_score(Y_test, Y_pred)
# Out:
# Accuracy of Gradient Boosting classifier on training set: 0.99
# Accuracy of Gradient Boosting classifier on test set: 0.99
#
# [[24478    82]
#  [  250   364]]
# 0.9868117899420037

# %%
from sklearn.tree import DecisionTreeClassifier

DT = DecisionTreeClassifier()
DT.fit(X_train,Y_train)

print('Accuracy of Decision Tree classifier on training set: {:.2f}'
     .format(DT.score(X_train, Y_train)))
print('Accuracy of Decision Tree classifier on test set: {:.2f}'
     .format(DT.score(X_test, Y_test)))

print()
Y_pred = DT.predict(X_test)
print(confusion_matrix(Y_test, Y_pred))
print()
metrics.accuracy_score(Y_test, Y_pred)
# Out:
# Accuracy of Decision Tree classifier on training set: 0.99
# Accuracy of Decision Tree classifier on test set: 0.99
#
# [[24475    85]
#  [  240   374]]
# 0.9870898546119011

# %%
from sklearn.neighbors import KNeighborsClassifier

KNN = KNeighborsClassifier(n_neighbors = 5)
KNN.fit(X_train, Y_train)

print('Accuracy of K-NN classifier on training set: {:.2f}'
     .format(KNN.score(X_train, Y_train)))
print('Accuracy of K-NN classifier on test set: {:.2f}'
     .format(KNN.score(X_test, Y_test)))

print()
Y_pred = KNN.predict(X_test)
print(confusion_matrix(Y_test, Y_pred))
print()
metrics.accuracy_score(Y_test, Y_pred)
# Out:
# Accuracy of K-NN classifier on training set: 0.99
# Accuracy of K-NN classifier on test set: 0.99
#
# [[24481    79]
#  [  238   376]]
# 0.9874076428060697

# %%
from sklearn.ensemble import RandomForestClassifier

RF = RandomForestClassifier()
RF.fit(X_train,Y_train)

print('Accuracy of Random Forest classifier on training set: {:.2f}'
     .format(RF.score(X_train, Y_train)))
print('Accuracy of Random Forest classifier on test set: {:.2f}'
     .format(RF.score(X_test, Y_test)))

print()
Y_pred = RF.predict(X_test)
print(confusion_matrix(Y_test, Y_pred))
print()
metrics.accuracy_score(Y_test, Y_pred)
# Out:
# Accuracy of Random Forest classifier on training set: 0.99
# Accuracy of Random Forest classifier on test set: 0.99
#
# [[24471    89]
#  [  231   383]]
# 0.9872884722332566

# %%
import pickle
filename = 'PT.sav'                                           #Edit this
pickle.dump(KNN, open(filename, 'wb'))                         #Change GB if needed
#loaded_model = pickle.load(open(filename, 'rb'))
#result = loaded_model.score(X_test, Y_test)
#print(result)
# !cp PT.sav "drive/My Drive/MODEL"                             # replace OS.sav with file name
